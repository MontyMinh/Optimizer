# %%
import numpy as np

# %%
def generate_constraints_vector(self):

    self.constraints_vector = np.vstack([
        self.demand_bulk, self.demand_bag, self.capacity_bulk,
        self.capacity_total,
        np.zeros((self.no_factories, 1))
    ])
